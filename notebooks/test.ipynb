# %%
print("hello world")

# %%
a = 20

# %%
print(a)
# Out:
# 20

# %%
a * 20
# Out:
# 400

# %%
import time, sys
for i in range(8):
    print(i)
    time.sleep(0.5)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
